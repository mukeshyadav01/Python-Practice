# %% [markdown]
# <a href="https://colab.research.google.com/github/mukeshyadav01/Python-Practice/blob/main/week1_basics%20/%20day1_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.Print

# %%
print('mukesh')
# Out:
# mukesh

# %%
print('hello',2.7,True)
# Out:
# hello 2.7 True

# %%
print("hello",78,87,sep='/')
# Out:
# hello/78/87

# %%
print('mukesh')
print('world')
# Out:
# mukesh
# world

# %%
print('hello ram')
# Out:
# hello ram

# %%
print('hello mukesh how are you')
# Out:
# hello mukesh how are you

# %%
print('hello', end='-')
print('world')
# Out:
# hello-world

# %% [markdown]
# #2. Data  Types

# %%
# integer
print(8)
print(1e309)
# Out:
# 8
# inf

# %%
# Decimal/float
print(8.55)
print(1.7e300)
# Out:
# 8.55
# 1.7e+300

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# Text/String
print('hello World')
# Out:
# hello World

# %%
# complex
print(5+6)
# Out:
# 11

# %%
# List -> C->Array
print(1,2,3,4)
# Out:
# 1 2 3 4

# %%
# Sets
print({1,2,3,4.5,5})
# Out:
# {1, 2, 3, 4.5, 5}

# %%
# Tuple
print((1,2,3,4))
# Out:
# (1, 2, 3, 4)

# %%
# Dictionary
print({'name':'Mukesh','Gender':'Male','weight':60})
# Out:
# {'name': 'Mukesh', 'Gender': 'Male', 'weight': 60}

# %%
# type
type([6])
# Out:
# list

# %% [markdown]
# # 3. Variables

# %%
name ='Mukesh'
print(name)
# Out:
# Mukesh

# %%
a =5
b=6
print(5+6)
# Out:
# 11

# %%
# Dynamic Typing
a=5;
# Static Typing
# int a =5

# %%
# Dynamic Binding    ( Python support dynamic binding . Python ka jo variable hai vo usi program me text aur list kuch bhi hold kar sakta hai )
a =5
print(a)
a='Mukesh'
print(a)

# Static Binding
# int a=5;
# Out:
# 5
# Mukesh

# %%
a=5
b=8
c=0
print(a,c,b)
# Out:
# 5 0 8

# %%
a,b,c=3,5,7
print(a,b,c)
# Out:
# 3 5 7

# %% [markdown]
# # Comments

# %%
# this is a comment
a=4
b=7
print(a+b)
# Out:
# 11

# %% [markdown]
# # 4. Keywords & Identifiers

# %%
# Keywords
#there are 35 keywords in python
# False
# await
# else
# import
# pass
# None
# break
# except
# in
# raise
# True
# class
# finally
# is
# return
# and
# continue
# for
# lambda
# tr
# as
# def
# from
# nonlocal
# while
# assert
# del
# global
# not
# wit
# async
# elif
# if
# or
# yield

# %%
#identifiers
# 1. You can't start with a digit
name1 = 'Mukesh'
print(name1)
# 2.You can use special chars -> _
first_name ='Mukesh'
print(first_name)
# 3. Identifiers can not be keywords
# Out:
# Mukesh
# Mukesh

# %% [markdown]
# # 5. User Input

# %%
# Static vs Dynamic
input('Enter your name:')
# Out:
# Enter your name:Mukesh Yadav
# 'Mukesh Yadav'

# %%
#take input from user and store them in a variable
fnum = input('enter the first number:')
snum = input('Enter the second number:')
#add the two number
result = int(fnum) + int(snum)
#print the result
print(result)
print(type(fnum))
# Out:
# enter the first number:7
# Enter the second number:6
# 13
# <class 'str'>

# %% [markdown]
# # 6.Type Conversion

# %%
#Implicit vs Explicit
print(5+5.6)
print(type(5),type(5.6))
# Out:
# 10.6
# <class 'int'> <class 'float'>

# %%
#Explicit
#str -> int
# int(4+5j)

# %% [markdown]
# #7. Literals

# %%
#the value which is assign to variable
a = 0b1010       # Binary Literalss
b = 100          # Decimal Literals
c = 0o310        # Octal Literals
d = 0x12c        # Hexadecimal Literalss

#float Literals
float_1 = 10.4
float_2 = 1.5e2
float_3 = 1.5e-3
# Out:
# 10 100 200 300
